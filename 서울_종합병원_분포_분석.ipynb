# %% [markdown]
# <a href="https://colab.research.google.com/github/runnin123/Project/blob/master/%EC%84%9C%EC%9A%B8_%EC%A2%85%ED%95%A9%EB%B3%91%EC%9B%90_%EB%B6%84%ED%8F%AC_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 공공데이터 상권정보 분석
# - 출처: https://www.data.go.kr/ (공공데이터 포털)
# - '상가(상권) 정보_의료기관_201909'
# - 목표: 서울의 종합병원은 고르게 분포되어 있는가?

# %% [markdown]
# ## 1.1 라이브러리 불러오기
# - Numpy, Pandas, Seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 1.2 폰트 설정

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
# 나눔고딕 설치(설치 후 런타임 다시 시작)
# !apt -qq -y install fonts-nanum > /dev/null
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
fm._rebuild()
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')

# %%
plt.figure(figsize=(5,5))
plt.plot([0,1], [0,1], label='한글테스트용')
plt.legend()
plt.show()

# %% [markdown]
# ## 1.3 데이터 로드

# %%
# 상가(의료기관) 데이터 로드
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/소상공인시장진흥공단_상가업소정보_의료기관_201909.csv')
df.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (91335, 39)

# %% [markdown]
# ## 1.4 데이터 미리보기

# %%
# 상위 5개 데이터 확인
df.head()
# Out:
#      상가업소번호        상호명  지점명 상권업종대분류코드  ...  층정보  호정보          경도         위도
# 0  19956873     하나산부인과  NaN         S  ...  NaN  NaN  126.814295  37.336344
# 1  20024149   타워광명내과의원  NaN         S  ...    4  NaN  127.053198  37.488742
# 2  20152277  조정현신경외과의원  NaN         S  ...  NaN  NaN  126.734841  37.344955
# 3  20350610   한귀원정신과의원  NaN         S  ...    5  NaN  129.115438  35.166872
# 4  20364049  더블유스토어수지점  수지점         S  ...    1  NaN  127.095522  37.323528
#
# [5 rows x 39 columns]

# %%
# 하위 5개 데이터 확인
df.tail()
# Out:
#          상가업소번호           상호명   지점명 상권업종대분류코드  ...  층정보  호정보          경도         위도
# 91330  16196725         온누리약국   베스트         S  ...  NaN  NaN  127.389865  36.352728
# 91331  16192180            리원  봄산후조         S  ...  NaN  NaN  126.830144  37.627530
# 91332  16127538       참좋은요양병원   NaN         S  ...    2  NaN  129.082790  35.227138
# 91333  16108681       경희중앙한의원   NaN         S  ...  NaN  NaN  127.143958  37.540993
# 91334  16109073  천안김안과천안역본점의원   NaN         S  ...  NaN  NaN  127.152651  36.806640
#
# [5 rows x 39 columns]

# %% [markdown]
# ## 1.5 데이터 요약

# %% [markdown]
# ### 1.5.1 요약정보

# %%
# 데이터 요약
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91335 entries, 0 to 91334
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상가업소번호     91335 non-null  int64
#  1   상호명        91335 non-null  object
#  2   지점명        1346 non-null   object
#  3   상권업종대분류코드  91335 non-null  object
#  4   상권업종대분류명   91335 non-null  object
#  5   상권업종중분류코드  91335 non-null  object
#  6   상권업종중분류명   91335 non-null  object
#  7   상권업종소분류코드  91335 non-null  object
#  8   상권업종소분류명   91335 non-null  object
#  9   표준산업분류코드   86413 non-null  object
#  10  표준산업분류명    86413 non-null  object
#  11  시도코드       90956 non-null  float64
#  12  시도명        90956 non-null  object
#  13  시군구코드      90956 non-null  float64
#  14  시군구명       90956 non-null  object
#  15  행정동코드      91335 non-null  int64
#  16  행정동명       90956 non-null  object
#  17  법정동코드      91280 non-null  float64
#  18  법정동명       91280 non-null  object
# ...

# %% [markdown]
# ### 1.5.2 컬럼명 확인

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %% [markdown]
# ### 1.5.3 데이터 타입

# %%
df.dtypes
# Out:
# 상가업소번호         int64
# 상호명           object
# 지점명           object
# 상권업종대분류코드     object
# 상권업종대분류명      object
# 상권업종중분류코드     object
# 상권업종중분류명      object
# 상권업종소분류코드     object
# 상권업종소분류명      object
# 표준산업분류코드      object
# 표준산업분류명       object
# 시도코드         float64
# 시도명           object
# 시군구코드        float64
# 시군구명          object
# 행정동코드          int64
# 행정동명          object
# 법정동코드        float64
# 법정동명          object
# 지번코드           int64
# 대지구분코드         int64
# 대지구분명         object
# 지번본번지          int64
# 지번부번지        float64
# 지번주소          object
# 도로명코드          int64
# 도로명           object
# 건물본번지          int64
# 건물부번지        float64
# 건물관리번호        object
# 건물명           object
# 도로명주소         object
# 구우편번호        float64
# 신우편번호        float64
# 동정보           object
# 층정보           object
# 호정보           object
# 경도           float64
# 위도           float64
# dtype: object

# %% [markdown]
# ## 1.6 결측치

# %%
# 결측치 개수 확인
null_count = df.isnull().sum()
null_count
# Out:
# 상가업소번호           0
# 상호명              0
# 지점명          89989
# 상권업종대분류코드        0
# 상권업종대분류명         0
# 상권업종중분류코드        0
# 상권업종중분류명         0
# 상권업종소분류코드        0
# 상권업종소분류명         0
# 표준산업분류코드      4922
# 표준산업분류명       4922
# 시도코드           379
# 시도명            379
# 시군구코드          379
# 시군구명           379
# 행정동코드            0
# 행정동명           379
# 법정동코드           55
# 법정동명            55
# 지번코드             0
# 대지구분코드           0
# 대지구분명            0
# 지번본번지            0
# 지번부번지        19256
# 지번주소             0
# 도로명코드            0
# 도로명              0
# 건물본번지            0
# 건물부번지        80731
# 건물관리번호           0
# 건물명          44882
# 도로명주소            0
# 구우편번호           12
# 신우편번호            2
# 동정보          83929
# 층정보          47291
# 호정보          75784
# 경도               0
# 위도               0
# dtype: int64

# %%
# 결측치 → 단순 그래프
null_count.plot()

# %%
# 결측치 → 막대 그래프
null_count.plot.bar(rot = 60) # rot: x축 이름 회전

# %%
# 결측치 → 막대 가로 그래프, 사이즈 조정
null_count.plot.barh(figsize = (5, 7))

# %%
# null_count 변수 → 데이터프레임에 저장
df_null_count = null_count.reset_index()
df_null_count.head()
# Out:
#        index      0
# 0     상가업소번호      0
# 1        상호명      0
# 2        지점명  89989
# 3  상권업종대분류코드      0
# 4   상권업종대분류명      0

# %% [markdown]
# ## 1.7 컬럼명 변경하기

# %%
# 컬럼명 확인
df_null_count.columns
# Out:
# Index(['index', 0], dtype='object')

# %%
df_null_count.columns = ['컬럼명', '결측치수']
df_null_count.head()
# Out:
#          컬럼명   결측치수
# 0     상가업소번호      0
# 1        상호명      0
# 2        지점명  89989
# 3  상권업종대분류코드      0
# 4   상권업종대분류명      0

# %% [markdown]
# ## 1.8 정렬

# %%
# 결측치 많은 순으로 정렬, 상위 10개 출력
df_null_count_top = df_null_count.sort_values(by = '결측치수', ascending = False).head(10)
df_null_count_top
# Out:
#          컬럼명   결측치수
# 2        지점명  89989
# 34       동정보  83929
# 28     건물부번지  80731
# 36       호정보  75784
# 35       층정보  47291
# 30       건물명  44882
# 23     지번부번지  19256
# 9   표준산업분류코드   4922
# 10   표준산업분류명   4922
# 11      시도코드    379

# %% [markdown]
# ## 1.9 특정 컬럼 불러오기

# %%
# 지점명 컬럼
df['지점명'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    수지점
# Name: 지점명, dtype: object

# %%
# '컬럼명' 컬럼 값 → 변수에 리스트 형태로 저장
drop_columns = df_null_count_top['컬럼명'].tolist()
drop_columns
# Out:
# ['지점명',
#  '동정보',
#  '건물부번지',
#  '호정보',
#  '층정보',
#  '건물명',
#  '지번부번지',
#  '표준산업분류코드',
#  '표준산업분류명',
#  '시도코드']

# %%
# 'drop_columns'에 해당하는 정보만 추출
df[drop_columns].head()
# Out:
#    지점명  동정보  건물부번지  호정보  층정보      건물명  지번부번지 표준산업분류코드         표준산업분류명  시도코드
# 0  NaN  NaN    NaN  NaN  NaN  산호한양아파트    NaN   Q86201           일반 의원  41.0
# 1  NaN  NaN    NaN  NaN    4      NaN   14.0   Q86201           일반 의원  11.0
# 2  NaN  NaN    NaN  NaN  NaN    한라프라자    1.0   Q86201           일반 의원  41.0
# 3  NaN  NaN    NaN  NaN    5      NaN    1.0      NaN             NaN  26.0
# 4  수지점  NaN    NaN  NaN    1      NaN    2.0   G47811  의약품 및 의료용품 소매업  41.0

# %% [markdown]
# ## 1.10 결측치 제거

# %%
# axis = 0: 열 기준, axis = 1: 행 기준 / 갯수 비교
print(df.shape)
df = df.drop(drop_columns, axis = 1)
print(df.shape)
# Out:
# (91335, 39)
# (91335, 29)

# %%
# 제거 후 데이터 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91335 entries, 0 to 91334
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상가업소번호     91335 non-null  int64
#  1   상호명        91335 non-null  object
#  2   상권업종대분류코드  91335 non-null  object
#  3   상권업종대분류명   91335 non-null  object
#  4   상권업종중분류코드  91335 non-null  object
#  5   상권업종중분류명   91335 non-null  object
#  6   상권업종소분류코드  91335 non-null  object
#  7   상권업종소분류명   91335 non-null  object
#  8   시도명        90956 non-null  object
#  9   시군구코드      90956 non-null  float64
#  10  시군구명       90956 non-null  object
#  11  행정동코드      91335 non-null  int64
#  12  행정동명       90956 non-null  object
#  13  법정동코드      91280 non-null  float64
#  14  법정동명       91280 non-null  object
#  15  지번코드       91335 non-null  int64
#  16  대지구분코드     91335 non-null  int64
#  17  대지구분명      91335 non-null  object
#  18  지번본번지      91335 non-null  int64
# ...

# %% [markdown]
# ## 1.11 기초 통계값

# %% [markdown]
# ### 1.11.1 기초 통계 수치
# - int / float 타입만 파악 가능

# %%
# 평균값
df['위도'].mean()
# Out:
# 36.62471119236673

# %%
# 중앙값
df['위도'].median()
# Out:
# 37.23465231770329

# %%
# 최댓값
df['위도'].max()
# Out:
# 38.499658570559795

# %%
# 최솟값
df['위도'].min()
# Out:
# 33.2192896688307

# %%
# 갯수
df['위도'].count()
# Out:
# 91335

# %% [markdown]
# ### 1.11.2 기초 통계값 요약(describe)
# - 개수, 평균, 편차, 최소값, 1사분위수, 2사분위수, 3사분위수, 최대값

# %%
df['위도'].describe()
# Out:
# count    91335.000000
# mean        36.624711
# std          1.041361
# min         33.219290
# 25%         35.811830
# 50%         37.234652
# 75%         37.507463
# max         38.499659
# Name: 위도, dtype: float64

# %%
# 2개 컬럼 요약
df[['위도', '경도']].describe()
# Out:
#                  위도            경도
# count  91335.000000  91335.000000
# mean      36.624711    127.487524
# std        1.041361      0.842877
# min       33.219290    124.717632
# 25%       35.811830    126.914297
# 50%       37.234652    127.084550
# 75%       37.507463    128.108919
# max       38.499659    130.909912

# %%
# 문자열 데이터타입 확인: count, unique, top, freq
# top: 가장 높은 빈도로 저장된 데이터
# freq: 위 데이터의 빈도수
df.describe(include = 'object')
# Out:
#           상호명 상권업종대분류코드  ...                     건물관리번호                  도로명주소
# count   91335     91335  ...                      91335                  91335
# unique  56910         1  ...                      54142                  54031
# top        리원         S  ...  1123010300109650001031604  서울특별시 동대문구 약령중앙로8길 10
# freq      152     91335  ...                        198                    198
#
# [4 rows x 16 columns]

# %% [markdown]
# ### 1.11.3 중복제거
# - unique(): 중복 제거 값 확인
# - nunique(): 중복 제거 값 갯수

# %%
df['상권업종대분류명'].unique()
# Out:
# array(['의료'], dtype=object)

# %%
df['상권업종대분류명'].nunique()
# Out:
# 1

# %%
df['상권업종중분류명'].unique()
# Out:
# array(['병원', '약국/한약방', '수의업', '유사의료업', '의료관련서비스업'], dtype=object)

# %%
df['상권업종중분류명'].nunique()
# Out:
# 5

# %%
df['상권업종소분류명'].unique()
# Out:
# array(['산부인과', '내과/외과', '신경외과', '기타병원', '약국', '동물병원', '한약방', '탕제원',
#        '정형/성형외과', '소아과', '이비인후과의원', '노인/치매병원', '언어치료', '수의업-종합', '한의원',
#        '치과의원', '침구원', '일반병원', '안과의원', '조산원', '한방병원', '종합병원', '유사의료업기타',
#        '응급구조대', '혈액원', '치과병원', '척추교정치료', '피부과', '비뇨기과', '치과기공소', '산후조리원',
#        '접골원', '수의업-기타', '제대혈'], dtype=object)

# %%
df['상권업종소분류명'].nunique()
# Out:
# 34

# %%
# len 사용
len(df['상권업종소분류명'].unique())
# Out:
# 34

# %% [markdown]
# ### 1.11.4 그룹화 후 요약값 확인

# %%
# 시도명
df['시도명'].head()
# Out:
# 0      경기도
# 1    서울특별시
# 2      경기도
# 3    부산광역시
# 4      경기도
# Name: 시도명, dtype: object

# %%
# 시도명 개수 확인
city = df['시도명'].value_counts()
city
# Out:
# 경기도        21374
# 서울특별시      18943
# 부산광역시       6473
# 경상남도        4973
# 인천광역시       4722
# 대구광역시       4597
# 경상북도        4141
# 전라북도        3894
# 충청남도        3578
# 전라남도        3224
# 광주광역시       3214
# 대전광역시       3067
# 충청북도        2677
# 강원도         2634
# 울산광역시       1997
# 제주특별자치도     1095
# 세종특별자치시      353
# Name: 시도명, dtype: int64

# %%
# 비율 확인: normalize = True
city_normalize = df['시도명'].value_counts(normalize = True)
city_normalize
# Out:
# 경기도        0.234993
# 서울특별시      0.208266
# 부산광역시      0.071166
# 경상남도       0.054675
# 인천광역시      0.051915
# 대구광역시      0.050541
# 경상북도       0.045528
# 전라북도       0.042812
# 충청남도       0.039338
# 전라남도       0.035446
# 광주광역시      0.035336
# 대전광역시      0.033720
# 충청북도       0.029432
# 강원도        0.028959
# 울산광역시      0.021956
# 제주특별자치도    0.012039
# 세종특별자치시    0.003881
# Name: 시도명, dtype: float64

# %%
# city → 그래프
city.plot.barh()

# %%
# city_normalize → pie chart
city_normalize.plot.pie(figsize = (8, 8))

# %% [markdown]
# - pie chart: 서울과 경기도의 차이를 파악하기가 힘듦

# %%
# seaborn → countplot(x, y 둘 중 하나만 써주는 편)
c = sns.countplot(data = df, y = '시도명')

# %%
# '상권업종대분류명' 갯수
df['상권업종대분류명'].value_counts()
# Out:
# 의료    91335
# Name: 상권업종대분류명, dtype: int64

# %%
# '상권업종중분류명' 갯수
c = df['상권업종중분류명'].value_counts()
c
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
# '상권업종중분류명' 비율
n = df['상권업종중분류명'].value_counts(normalize = True)
n
# Out:
# 병원          0.665397
# 약국/한약방      0.229080
# 수의업         0.058280
# 유사의료업       0.041320
# 의료관련서비스업    0.005923
# Name: 상권업종중분류명, dtype: float64

# %%
# 시각화 (막대 그래프)
c.plot.bar(rot = 0)

# %%
# pie chart
n.plot.pie()

# %%
# '상권업종소분류명' 개수
c = df['상권업종소분류명'].value_counts()
c
# Out:
# 약국         18964
# 치과의원       13731
# 한의원        13211
# 내과/외과      11374
# 기타병원        4922
# 일반병원        3385
# 동물병원        3098
# 정형/성형외과     2562
# 소아과         2472
# 수의업-종합      2216
# 치과기공소       1724
# 이비인후과의원     1486
# 한약방         1442
# 피부과         1273
# 산부인과        1116
# 노인/치매병원     1055
# 안과의원        1042
# 비뇨기과         809
# 종합병원         762
# 치과병원         756
# 언어치료         664
# 유사의료업기타      629
# 탕제원          517
# 산후조리원        511
# 신경외과         421
# 한방병원         397
# 척추교정치료       338
# 침구원          154
# 혈액원          130
# 응급구조대        125
# 조산원           30
# 접골원            9
# 수의업-기타         9
# 제대혈            1
# Name: 상권업종소분류명, dtype: int64

# %%
# 시각화
c.plot.barh(figsize = (7, 8), grid = True) # grid = True: 격자 표시

# %% [markdown]
# ## 1.12 데이터 색인

# %%
# '상권업종중분류명' → '약국/한약방' (boolean indexing 사용)
df_medical = df[df['상권업종중분류명'] == '약국/한약방'].copy()
df_medical.head()
# Out:
#       상가업소번호        상호명 상권업종대분류코드  ...    신우편번호          경도         위도
# 4   20364049  더블유스토어수지점         S  ...  16837.0  127.095522  37.323528
# 6   20733252      춘산한약방         S  ...  24273.0  127.726905  37.880504
# 7   20582210      부부탕제원         S  ...  28726.0  127.499206  36.625355
# 10  21057519       민생약국         S  ...  50212.0  128.118615  35.575962
# 13  21217689     제중당한약방         S  ...  58429.0  126.630348  34.834080
#
# [5 rows x 29 columns]

# %%
# '상권업종대분류명' → '의료'인 데이터의 '상권업종중분류명'(loc 사용)
m = df['상권업종대분류명'] == '의료'
df.loc[m, '상권업종중분류명'].value_counts()
# df.loc[df['상권업종대분류명'] == '의료', '상권업종중분류명'].value_counts()
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
# 유사의료업
df_medi = df[df['상권업종중분류명'] == '유사의료업']
df_medi.shape
# Out:
# (3774, 29)

# %%
# 상호명 개수
df['상호명'].value_counts().head(10)
# Out:
# 리원       152
# 온누리약국    149
# 경희한의원    141
# 우리약국     119
# 중앙약국     111
# 전자담배      98
# 조은약국      95
# 건강약국      87
# 제일약국      79
# 사랑약국      73
# Name: 상호명, dtype: int64

# %%
# 유사의료업의 상호명 확인
df_medi['상호명'].value_counts().head(10)
# Out:
# 리원          32
# 고려수지침       22
# 대한적십자사      17
# 헌혈의집        12
# 수치과기공소      10
# 고려수지침학회     10
# 제일치과기공소      9
# 이사랑치과기공소     8
# 어울림치과기공소     8
# 스마일치과기공소     8
# Name: 상호명, dtype: int64

# %% [markdown]
# ### 1.12.1 여러 조건 색인

# %%
# 상권업종소분류명 → 약국 & 시도명 → 서울특별시
df['상권업종소분류명'] == '약국'
df['시도명'] == '서울특별시'
df[(df['상권업종소분류명'] == '약국') & (df['시도명'] == '서울특별시')].head()
# Out:
#        상가업소번호      상호명 상권업종대분류코드  ...   신우편번호          경도         위도
# 33   20816709    이즈타워약         S  ...  6134.0  127.028023  37.498656
# 51   20855710     진흥약국         S  ...  5360.0  127.145055  37.534135
# 130  21589838    신세계약국         S  ...  2024.0  127.092597  37.616424
# 136  22388303  메디팜한솔약국         S  ...  4717.0  127.027513  37.556238
# 141  22412563      명약국         S  ...  2498.0  127.060556  37.587349
#
# [5 rows x 29 columns]

# %%
df_seoul_drug = df[(df['상권업종소분류명'] == '약국') & (df['시도명'] == '서울특별시')]
print(df_seoul_drug.shape)
df_seoul_drug.head(1)
# Out:
# (3579, 29)
#       상가업소번호    상호명 상권업종대분류코드 상권업종대분류명  ...     구우편번호   신우편번호          경도         위도
# 33  20816709  이즈타워약         S       의료  ...  135080.0  6134.0  127.028023  37.498656
#
# [1 rows x 29 columns]

# %% [markdown]
# ### 1.12.2 구별 확인

# %%
# 시군구 확인
c = df_seoul_drug['시군구명'].value_counts()
c.head()
# Out:
# 강남구     374
# 동대문구    261
# 광진구     212
# 서초구     191
# 송파구     188
# Name: 시군구명, dtype: int64

# %%
# 비율 확인
n = df_seoul_drug['시군구명'].value_counts(normalize = True)
n.head()
# Out:
# 강남구     0.104498
# 동대문구    0.072925
# 광진구     0.059234
# 서초구     0.053367
# 송파구     0.052529
# Name: 시군구명, dtype: float64

# %%
# 시각화
c.plot.bar(rot = 60)

# %%
# 종합병원 + 서울특별시
df_seoul_hospital = df[(df['상권업종소분류명'] == '종합병원') & (df['시도명'] == '서울특별시')].copy()
df_seoul_hospital
# Out:
#          상가업소번호               상호명 상권업종대분류코드  ...   신우편번호          경도         위도
# 305    25155642            대진의료재단         S  ...  4944.0  127.088279  37.559048
# 353    20471487            홍익병원별관         S  ...  7937.0  126.862805  37.529213
# 385    20737057              SNUH         S  ...  6236.0  127.035825  37.499630
# 1917   23210677  평화드림여의도성모병원의료기매장         S  ...  7345.0  126.936693  37.518296
# 2461   20024045                한양         S  ...  4763.0  127.041325  37.559469
# ...         ...               ...       ...  ...     ...         ...        ...
# 71991  28505952      서울성모병원응급의료센터         S  ...  6591.0  127.005841  37.502382
# 76508  12292992             라마르의원         S  ...  5335.0  127.127466  37.538485
# 90492  16031909     가톨릭대학교여의도성모병원         S  ...  4537.0  126.986758  37.563662
# 90581  16332576              씨엠병원         S  ...  7301.0  126.903857  37.518807
# 90788  16162338            성베드로병원         S  ...  6271.0  127.039567  37.485604
#
# ...

# %%
# 구별 종합병원 수
df_seoul_hospital['시군구명'].value_counts()
# Out:
# 강남구     15
# 영등포구     8
# 광진구      6
# 서초구      6
# 송파구      5
# 강동구      5
# 중구       5
# 도봉구      4
# 양천구      4
# 강북구      4
# 서대문구     4
# 성북구      3
# 종로구      2
# 노원구      2
# 관악구      2
# 금천구      2
# 구로구      2
# 성동구      2
# 강서구      2
# 중랑구      2
# 동대문구     2
# 마포구      1
# 은평구      1
# 동작구      1
# 용산구      1
# Name: 시군구명, dtype: int64

# %% [markdown]
# ### 1.12.3 텍스트 데이터 색인

# %%
# 상호명에 종합병원이 아닌 데이터의 상호명 확인
# not 조건: '~' 사용/ 텍스트 포함: str.contains()
df_seoul_hospital.loc[~df_seoul_hospital['상호명'].str.contains('종합병원'), '상호명'].unique()
# Out:
# array(['대진의료재단', '홍익병원별관', 'SNUH', '평화드림여의도성모병원의료기매장', '한양', '백산의료재단친구병원',
#        '서울보훈병원', '서울성모병원장례식장꽃배달', '서울대학교병원', '알콜중독및정신질환상담소',
#        '강남성모병원장례식장꽃배달', '제일병원', '이랜드클리닉', '사랑나눔의료재단', '우울증센터', '성심의료재단',
#        '다나의료재단', '서울아산병원신관', '원자력병원장례식장', '국민의원', '고려대학교구로병원', '학교법인일송학원',
#        '삼성의료원장례식장', '희명스포츠의학센터인공신장실', '연세대학교의과대학강남세브란스', '국립정신병원',
#        '코아클리닉', '수서제일의원', '사랑의의원', '한국전력공사부속한일병원', '신촌연세병원', '창동제일의원',
#        '영동세브란스병원', '제일성심의원', '삼성의료재단강북삼성태', '서울시립보라매병원', '서울이의원',
#        '서울대학교병원비상계획외래', '평화드림서울성모병원의료', '홍익병원', '사랑나눔의료재단서', '독일의원',
#        '서울연합의원', '우신향병원', '동부제일병원', '아산재단금강병원', '명곡안연구소', '아산재단서울중앙병원',
#        '메디힐특수여객', '삼성생명공익재단삼성서', '성광의료재단차병원', '한국건강관리협회서울특',
#        '정해복지부설한신메디피아', '성베드로병원', '성애의료재단', '실로암의원', 'Y&T성모마취과', '광진성모의원',
#        '서울현대의원', '이노신경과의원', '송정훼밀리의원', '서울중앙의원', '영남의료재단', '인제대학교서울백병원',
#        '한국필의료재단', '세브란스의원', '가톨릭대학교성바오로병원장례식장', '서울연세의원', '사랑의병원',
#        '성삼의료재단미즈메디병원', '씨엠충무병원', '성신의원', '원진재단부설녹색병원', '송파제일의원',
# ...

# %% [markdown]
# - 상담소, 센터, 인공심장실, 의원, 장례식장, 어린이집, 꽃배달 등 부적절한 상호명이 포함됨

# %%
# '꽃배달' 포함 데이터 확인
df_seoul_hospital[df_seoul_hospital['상호명'].str.contains('꽃배달')]
# Out:
#         상가업소번호            상호명 상권업종대분류코드  ...   신우편번호          경도         위도
# 2803  20895655  서울성모병원장례식장꽃배달         S  ...  6578.0  127.000682  37.498257
# 4644  22020310  강남성모병원장례식장꽃배달         S  ...  6578.0  127.001756  37.499095
#
# [2 rows x 29 columns]

# %%
# '의료기' 포함 데이터 확인
df_seoul_hospital[df_seoul_hospital['상호명'].str.contains('의료기')]
# Out:
#         상가업소번호               상호명 상권업종대분류코드  ...   신우편번호          경도         위도
# 1917  23210677  평화드림여의도성모병원의료기매장         S  ...  7345.0  126.936693  37.518296
#
# [1 rows x 29 columns]

# %%
# 꽃배달, 의료기, 장례식장, 상담소, 어린이집 → 모두 제거하기 위해 한 번에 검색
df_seoul_hospital[df_seoul_hospital['상호명'].str.contains('꽃배달|의료기|장례식장|상담소|어린이집')]
# Out:
#          상가업소번호                상호명 상권업종대분류코드  ...   신우편번호          경도         위도
# 1917   23210677   평화드림여의도성모병원의료기매장         S  ...  7345.0  126.936693  37.518296
# 2803   20895655      서울성모병원장례식장꽃배달         S  ...  6578.0  127.000682  37.498257
# 4431   21781516       알콜중독및정신질환상담소         S  ...  1411.0  127.046203  37.657046
# 4644   22020310      강남성모병원장례식장꽃배달         S  ...  6578.0  127.001756  37.499095
# 7938   20625484          원자력병원장례식장         S  ...  1812.0  127.082670  37.628808
# 10283  20024377          삼성의료원장례식장         S  ...  6351.0  127.089579  37.490334
# 47008  21738670   가톨릭대학교성바오로병원장례식장         S  ...  2559.0  127.043471  37.579246
# 60645  27670796         서울성모병원어린이집         S  ...  6591.0  127.005841  37.502382
# 70177  11537223  한림대학교부속한강성심병원장례식장         S  ...  7247.0  126.909676  37.523168
#
# [9 rows x 29 columns]

# %%
# 제거할 데이터의 인덱스 저장, 리스트로 변환
drop_row = df_seoul_hospital[df_seoul_hospital['상호명'].str.contains('꽃배달|의료기|장례식장|상담소|어린이집')].index
drop_row = drop_row.tolist()
drop_row
# Out:
# [1917, 2803, 4431, 4644, 7938, 10283, 47008, 60645, 70177]

# %%
# '의원' 데이터 역시 따로 저장, 리스트로 변환
# '의원'으로 끝나는 상호명: str.endswith() 사용
df_seoul_hospital[df_seoul_hospital['상호명'].str.endswith('의원')]
# Out:
#          상가업소번호      상호명 상권업종대분류코드  ...   신우편번호          경도         위도
# 8479    3723018     국민의원         S  ...  3758.0  126.956949  37.557573
# 12854  24551577   수서제일의원         S  ...  6347.0  127.099735  37.492133
# 13715  22439885    사랑의의원         S  ...  3742.0  126.964070  37.559888
# 14966  20410787   창동제일의원         S  ...  1405.0  127.045430  37.651877
# 16091  24550477   제일성심의원         S  ...  1138.0  127.033977  37.633231
# 18047  24318286    서울이의원         S  ...  2538.0  127.057837  37.573973
# 20200  24427239     독일의원         S  ...  4930.0  127.082699  37.556265
# 20415  26232681   서울연합의원         S  ...  5564.0  127.086652  37.508774
# 30706  24641665    실로암의원         S  ...  1882.0  127.054145  37.629538
# 32889  26667863   광진성모의원         S  ...  5074.0  127.068210  37.535527
# 34459  27060367   서울현대의원         S  ...  7548.0  126.855201  37.560343
# 34720  27324126  이노신경과의원         S  ...  6025.0  127.029429  37.523672
# ...

# %%
# 인덱스 저장, 리스트로 변환
drop_row2 = df_seoul_hospital[df_seoul_hospital['상호명'].str.endswith('의원')].index
drop_row2 = drop_row2.tolist()
drop_row2
# Out:
# [8479,
#  12854,
#  13715,
#  14966,
#  16091,
#  18047,
#  20200,
#  20415,
#  30706,
#  32889,
#  34459,
#  34720,
#  35696,
#  37251,
#  45120,
#  49626,
#  51575,
#  55133,
#  56320,
#  56404,
#  56688,
#  57551,
#  62113,
#  76508]

# %%
# drop_row + drop_row2
drop_row = drop_row + drop_row2
len(drop_row)
# Out:
# 33

# %%
# 해당 셀 삭제, 전후 갯수 비교
print(df_seoul_hospital.shape)
df_seoul_hospital = df_seoul_hospital.drop(drop_row,axis = 0) # row 삭제
print(df_seoul_hospital.shape)
# Out:
# (91, 29)
# (58, 29)

# %%
# 시각화
df_seoul_hospital['시군구명'].value_counts().plot.bar()

# %%
# countplot 시각화
plt.figure(figsize = (15, 4)) # 그래프 크기 설정
# order: 정렬
sns.countplot(data = df_seoul_hospital, x = '시군구명', order = df_seoul_hospital['시군구명'].value_counts().index)

# %%
df_seoul_hospital['상호명'].unique()
# Out:
# array(['대진의료재단', '홍익병원별관', 'SNUH', '한양', '백산의료재단친구병원', '서울보훈병원',
#        '서울대학교병원', '제일병원', '이랜드클리닉', '사랑나눔의료재단', '우울증센터', '성심의료재단',
#        '다나의료재단', '서울아산병원신관', '고려대학교구로병원', '학교법인일송학원', '희명스포츠의학센터인공신장실',
#        '연세대학교의과대학강남세브란스', '국립정신병원', '코아클리닉', '한국전력공사부속한일병원', '신촌연세병원',
#        '영동세브란스병원', '삼성의료재단강북삼성태', '서울시립보라매병원', '서울대학교병원비상계획외래',
#        '평화드림서울성모병원의료', '홍익병원', '사랑나눔의료재단서', '우신향병원', '동부제일병원', '아산재단금강병원',
#        '명곡안연구소', '아산재단서울중앙병원', '메디힐특수여객', '삼성생명공익재단삼성서', '성광의료재단차병원',
#        '한국건강관리협회서울특', '정해복지부설한신메디피아', '성베드로병원', '성애의료재단', 'Y&T성모마취과',
#        '영남의료재단', '인제대학교서울백병원', '한국필의료재단', '사랑의병원', '성삼의료재단미즈메디병원',
#        '씨엠충무병원', '원진재단부설녹색병원', '강남센트럴병원', '우리들병원', '건국대학교병원', '서울적십자병원',
#        '서울성모병원응급의료센터', '가톨릭대학교여의도성모병원', '씨엠병원'], dtype=object)

# %% [markdown]
# - 여전히 의료재단, 연구소 등 전처리해야 할 상호명이 남아있음

# %% [markdown]
# ### 1.12.4 특정 지역 데이터 확인

# %%
# 서울 데이터 추출, 저장
df_seoul = df[df['시도명'] == '서울특별시'].copy()
df_seoul.shape
# Out:
# (18943, 29)

# %%
# 시군구별 확인 (기본 pandas plot)
df_seoul['시군구명'].value_counts().plot.bar(figsize = (10, 4), rot = 30)

# %%
# 시군구별 확인 (seaborn: countplot)
plt.figure(figsize = (15, 4))
sns.countplot(data = df_seoul, x = '시군구명')

# %%
# 판다스 plot.scatter → 경도, 위도 표시
# x축, y축 데이터 필요
df_seoul[['경도', '위도', '시군구명']].plot.scatter(x = '경도', y = '위도', figsize = (8, 7), grid = True)

# %% [markdown]
# - 위도, 경도를 scatter plot으로 표현했더니 서울 시 모양으로 그 갯수가 산점도로 표현됨

# %%
# seaborn scatterplot → 경도, 위도 표시
# hue: 색상 표시
plt.figure(figsize = (9, 8))
sns.scatterplot(data = df_seoul, x = '경도', y = '위도', hue = '시군구명')

# %%
# 상권업종중분류명 → 경도, 위도 표시
plt.figure(figsize = (9, 8))
sns.scatterplot(data = df_seoul, x = '경도', y = '위도', hue = '상권업종중분류명')

# %%
# 전국 데이터 → 위도, 경도
plt.figure(figsize = (16, 12))
sns.scatterplot(data = df, x = '경도', y = '위도', hue = '시도명')

# %% [markdown]
# ## 1.13 Folium → 지도 활용

# %%
# !pip install folium

# %%
# 라이브러리 임포트
import folium

# %%
# 서울 종합병원 위치의 위도 값 평균
df_seoul_hospital['위도'].mean()
# Out:
# 37.52972276355594

# %%
# 서울 종합병원 위치의 경도 값 평균
df_seoul_hospital['경도'].mean()
# Out:
# 126.9963589356625

# %%
# 지도 중심 설정
map = folium.Map(location = [df_seoul_hospital['위도'].mean(), df_seoul_hospital['경도'].mean()],
           zoom_start = 12) # zoom_start: 시작 화면의 줌 정도

# for 반복 → 마커 표시
for n in df_seoul_hospital.index:
  name = df_seoul_hospital.loc[n, '상호명'] # 마커 표기용 상호명 저장
  address = df_seoul_hospital.loc[n, '도로명주소'] # 마커 표기용 도로명주소 저장
  popup = f'{name}-{address}' # 팝업 표기 → 포맷팅 문자열 이용
  location = [df_seoul_hospital.loc[n, '위도'], df_seoul_hospital.loc[n, '경도']]
  folium.Marker(
      location = location,
      popup = popup,
  ).add_to(map)
  map.save('index.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
